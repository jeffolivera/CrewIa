# %%
from dotenv import load_dotenv
_ = load_dotenv()
from crewai import Crew, Process, Agent, Task

# %%
planejador_de_viagem = Agent(
    role="planejador_de_viagem",
    goal="Planejar todos os detalhes de uma viagem, incluindo transporte, hospedagem, roteiro, alimentação e atividades.",
    backstory="""
    Você é um especialita em planejamento de viagens, sempre em busca de novas aventuras e experiências. Seu objetivo é garantir os detalhes das viagens
    sejam organizados de maneira eficiente e agradável. Você tem um vasto conhecimento sobre destinos turísticos, opções de transporte, hospedagem e atividades locais.
    Você é apaixonado por explorar novos lugares e culturas, e está sempre atualizado sobre as melhores práticas de planejamento de viagens.
    Você é um planejador meticuloso, sempre atento aos detalhes e às preferências dos viajantes. Sua missão é criar roteiros personalizados que atendam às necessidades
    e desejos de cada viajante, garantindo que cada viagem seja uma experiência inesquecível.
    """,
    verbose=True
)

# %%
orcamentista = Agent(
    role="orcamentista de viagens",
    goal="Criar orçamentos detalhados e precisos para viagens, considerando todos os custos envolvidos.: Transporte, hospedagem, alimentação e atividades.",
    backstory="""
    Você é um analista financeiro focado em viagens, sempre em busca de maneiras de otimizar os custos e maximizar o valor das experiências. Seu objetivo é garantir que
    cada viagem seja financeiramente viável e que os viajantes tenham uma compreensão clara dos custos envolvidos. Você tem um vasto conhecimento sobre preços de passagens,
    hospedagem, alimentação e atividades locais.
    Você é apaixonado por ajudar os viajantes a economizar dinheiro sem comprometer a qualidade da experiência. Sua missão é criar orçamentos detalhados que atendam às
    necessidades financeiras dos viajantes, garantindo que cada viagem seja acessível e dentro do orçamento.
    """,
    verbose=True
)

# %%
planeja_roteiro = Task(
    description="Crie um roteiro detalhado para a viagem na Europa, incluindo transporte, hospedagem, alimentação e atividades.",
    agent=planejador_de_viagem,
    expected_output="""
    Um roteiro com a sequencia de cidades a serem visitadas, os meios de transporte, as opções de hospedagem, as atividades planejadas e as refeições sugeridas.
    """
)

# %%
estima_orcamento = Task(
    description="Calcule o orçamento total da viagem, incluindo transporte, hospedagem, alimentação e atividades.",
    agent=orcamentista,
    expected_output="""
    Um orçamento detalhado com todos os custos envolvidos na viagem, incluindo transporte, hospedagem, alimentação e atividades.
    """
)

# %%
viagem_crew = Crew(
    agents=[planejador_de_viagem, orcamentista],
    tasks=[planeja_roteiro, estima_orcamento],
    processes=Process.sequential
)

# %%
result = viagem_crew.kickoff()
# Out:
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: planejador_de_viagem                                                                                    │
# │                                                                                                                 │
# │  Task: Crie um roteiro detalhado para a viagem na Europa, incluindo transporte, hospedagem, alimentação e       │
# │  atividades.                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...
